# %%
import pandas as pd
import numpy as np
import requests

# %%
df_stream = pd.read_json("../StreamingHistory0.json")

# %%
df_stream
# Out:
#                endTime    artistName  \
# 0     2021-05-28 17:02  benny blanco
# 1     2021-05-28 17:06       Gryffin
# 2     2021-05-28 17:09   Tones And I
# 3     2021-05-28 17:24        Alesso
# 4     2021-05-28 20:08     NCT DREAM
# ...                ...           ...
# 3597  2021-10-02 17:43  Ankit Tiwari
# 3598  2021-10-02 17:48  Arya Acharya
# 3599  2021-10-02 17:48        Pritam
# 3600  2021-10-02 20:59       NCT 127
# 3601  2021-10-02 21:02         ATEEZ
#
#                                               trackName  msPlayed  \
# 0                     You (with Marshmello & Vance Joy)    160828
# 1                       Safe With Me (with Audrey Mika)    205164
# 2                                              Fly Away    133667
# 3                           Midnight (feat. Liam Payne)    213800
# 4                                             Hot Sauce     57320
# ...                                                 ...       ...
# ...

# %%
#creating new ID for each song (Combining Artist name, TrackName)
df_stream['UniqueID'] = df_stream['artistName'] + ":" + df_stream['trackName']

df_stream.head()
# Out:
#             endTime    artistName                          trackName  \
# 0  2021-05-28 17:02  benny blanco  You (with Marshmello & Vance Joy)
# 1  2021-05-28 17:06       Gryffin    Safe With Me (with Audrey Mika)
# 2  2021-05-28 17:09   Tones And I                           Fly Away
# 3  2021-05-28 17:24        Alesso        Midnight (feat. Liam Payne)
# 4  2021-05-28 20:08     NCT DREAM                          Hot Sauce
#
#    msPlayed                                        UniqueID
# 0    160828  benny blanco:You (with Marshmello & Vance Joy)
# 1    205164         Gryffin:Safe With Me (with Audrey Mika)
# 2    133667                            Tones And I:Fly Away
# 3    213800              Alesso:Midnight (feat. Liam Payne)
# 4     57320                             NCT DREAM:Hot Sauce

# %%
df_library = pd.read_json("../YourLibrary.json")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17972\1442822395.py in <module>
# ----> 1 df_library = pd.read_json("../YourLibrary.json")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     606         return json_reader
#     607
# --> 608     result = json_reader.read()
#     609     if should_close:
#     610         filepath_or_buffer.close()
#
# ...
